# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import time

import clientserver # import from our script
from threading import Thread

db = {
    "John Doe": "123456789",
    "Jane Doe": "1122334455"
}

server = clientserver.Server(db)

Thread(target=server.serve, daemon=True).start()

try:
	while True:
		time.sleep(1)
except KeyboardInterrupt:
    server.stop()

print("Server stopped")
# Out:
# 2025-10-30 12:25:32,322 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=1308, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 2025-10-30 12:25:32,324 - vs2lab.lab1.clientserver.Server - INFO - Server listening
# 2025-10-30 12:25:32,325 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:35,331 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:38,346 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:41,361 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:44,375 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:47,398 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:50,411 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:51,580 - vs2lab.lab1.clientserver.Server - INFO - Received {"type": "GETALL", "data": {"name": "John Doe"}} from ('127.0.0.1', 54848)
# 2025-10-30 12:25:51,581 - vs2lab.lab1.clientserver.Server - INFO - Sent {'data': {'John Doe': '123456789', 'Jane Doe': '1122334455'}} to ('127.0.0.1', 54848)
# 2025-10-30 12:25:51,582 - vs2lab.lab1.clientserver.Server - INFO - Connection closed from ('127.0.0.1', 54848)
# 2025-10-30 12:25:51,583 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:54,597 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:25:57,604 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:00,611 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:03,623 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:06,625 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:09,632 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:12,642 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:15,658 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:18,673 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:21,686 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:24,705 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:27,712 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:30,725 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# 2025-10-30 12:26:33,730 - vs2lab.lab1.clientserver.Server - INFO - Listening for connections
# Exception in thread 2025-10-30 12:26:36,347 - vs2lab.lab1.clientserver.Server - INFO - Server stopped.
# Thread-3 (serve):
# Server stopped
# Traceback (most recent call last):
#   File "C:\Users\matth\AppData\Roaming\uv\python\cpython-3.14.0rc3-windows-x86_64-none\Lib\threading.py", line 1081, in _bootstrap_inner
#     self._context.run(self.run)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "E:\local_projects\uni\vs2lab\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 788, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\matth\AppData\Roaming\uv\python\cpython-3.14.0rc3-windows-x86_64-none\Lib\threading.py", line 1023, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\local_projects\uni\vs2lab\lab1\clientserver.py", line 117, in serve
#     except socket.timeout:
#         ^^^^^^^^^^^^^
#   File "E:\local_projects\uni\vs2lab\lab1\clientserver.py", line 88, in listen
#     (connection, address) = self.sock.accept()  # returns new socket and address of client
#                             ~~~~~~~~~~~~~~~~^^
#   File "C:\Users\matth\AppData\Roaming\uv\python\cpython-3.14.0rc3-windows-x86_64-none\Lib\socket.py", line 298, in accept
#     fd, addr = self._accept()
#                ~~~~~~~~~~~~^^
# OSError: [WinError 10038] An operation was attempted on something that is not a socket

# %% [markdown]
# Finished
