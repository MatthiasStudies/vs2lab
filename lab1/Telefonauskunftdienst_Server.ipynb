# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import time

import clientserver # import from our script
from threading import Thread

db = {
    "John Doe": "123456789",
    "Jane Doe": "1122334455"
}

server = clientserver.Server(db)

Thread(target=server.serve, daemon=True).start()

try:
	while True:
		time.sleep(1)
except KeyboardInterrupt:
    server.stop()

print("Server stopped")
# Out:
# 2025-11-06 11:16:08,973 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=1304, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 2025-11-06 11:16:08,974 - vs2lab.lab1.clientserver.Server - INFO - Server listening
# 2025-11-06 11:16:19,392 - vs2lab.lab1.clientserver.Server - INFO - Received {"type": "GETALL", "data": {"name": "John Doe"}} from ('127.0.0.1', 53051)
# 2025-11-06 11:16:19,394 - vs2lab.lab1.clientserver.Server - INFO - Sent {'data': [{'name': 'John Doe', 'number': '123456789'}, {'name': 'Jane Doe', 'number': '1122334455'}]} to ('127.0.0.1', 53051)
# 2025-11-06 11:16:19,395 - vs2lab.lab1.clientserver.Server - INFO - Connection closed from ('127.0.0.1', 53051)
# 2025-11-06 11:16:33,984 - vs2lab.lab1.clientserver.Server - INFO - Server down
# 2025-11-06 11:16:33,985 - vs2lab.lab1.clientserver.Server - INFO - Server stopped
# Server stopped

# %% [markdown]
# Finished
