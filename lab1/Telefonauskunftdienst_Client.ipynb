# %% [markdown]
# ### Server Setup

# %% [markdown]
# ### Client

# %%
from pprint import pprint
import clientserver

client = clientserver.Client() # Create a client instance
response = client.call("GETALL", {"name": "John Doe"})

pprint(response)

client.close()
# Out:
# 2025-10-30 12:25:51,579 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=1272, family=2, type=1, proto=0, laddr=('127.0.0.1', 54848), raddr=('127.0.0.1', 50007)>
# 2025-10-30 12:25:51,580 - vs2lab.a1_layers.clientserver.Client - INFO - Calling server with 'GETALL' query and {'name': 'John Doe'}
# 2025-10-30 12:25:51,581 - vs2lab.a1_layers.clientserver.Client - INFO - Received response: {'data': {'John Doe': '123456789', 'Jane Doe': '1122334455'}}
# 2025-10-30 12:25:51,582 - vs2lab.a1_layers.clientserver.Client - INFO - Client closed socket
# {'data': {'Jane Doe': '1122334455', 'John Doe': '123456789'}}
