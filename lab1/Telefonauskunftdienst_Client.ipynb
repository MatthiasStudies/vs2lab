# %% [markdown]
# ## GETALL from server

# %%
from pprint import pprint
import clientserver

client = clientserver.Client() # Create a client instance
response = client.call("GETALL")

pprint(response)

client.close()
# Out:
# 2025-11-06 15:49:26,272 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=600, family=2, type=1, proto=0, laddr=('127.0.0.1', 55747), raddr=('127.0.0.1', 50007)>
# 2025-11-06 15:49:26,273 - vs2lab.a1_layers.clientserver.Client - INFO - Calling server with 'GET' query and {'name': 'John Doe'}
# 2025-11-06 15:49:26,275 - vs2lab.a1_layers.clientserver.Client - INFO - Received response: {'error': 'Name not found'}
# 2025-11-06 15:49:26,276 - vs2lab.a1_layers.clientserver.Client - INFO - Client closed socket
# {'error': 'Name not found'}

# %% [markdown]
# ## GET specific entry from server

# %%
from pprint import pprint
import clientserver

client = clientserver.Client() # Create a client instance

while True:
    try:
        name = input("Enter a name to look up (or 'exit' to quit): ")
        if name.lower() == 'exit':
            break
        response = client.call("GET", {"name": name})
        pprint(response)
    except KeyboardInterrupt:
        break

client.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[3], line 4
#       1 from pprint import pprint
#       2 import clientserver
# ----> 4 client = clientserver.Client() # Create a client instance
#       6 while True:
#       7     try:
#
# File ~\local_projects\uni\vs2lab\lab1\clientserver.py:145, in __init__(self)
#     143 self.sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#     144 self.sock.connect((const_cs.HOST, const_cs.PORT))
# --> 145 self.logger.info("Client connected to socket " + str(self.sock))
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
