# %% [markdown]
# ### Server Setup

# %% [markdown]
# ### Client

# %%
from pprint import pprint
import clientserver

client = clientserver.Client() # Create a client instance
response = client.call("GET", {"name": "John Doe"})

pprint(response)

client.close()
# Out:
# 2025-11-05 00:21:38,322 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=1312, family=2, type=1, proto=0, laddr=('127.0.0.1', 64630), raddr=('127.0.0.1', 50007)>
# 2025-11-05 00:21:38,323 - vs2lab.a1_layers.clientserver.Client - INFO - Calling server with 'GET' query and {'name': 'John Doe'}
# 2025-11-05 00:21:38,324 - vs2lab.a1_layers.clientserver.Client - INFO - Received response: {'data': {'name': 'John Doe', 'number': '123456789'}}
# 2025-11-05 00:21:38,325 - vs2lab.a1_layers.clientserver.Client - INFO - Client closed socket
# {'data': {'name': 'John Doe', 'number': '123456789'}}
